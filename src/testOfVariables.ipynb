# %% [markdown]
# Test of which variables to remove from dataset

# %% [markdown]
# ## Part 1: Introduction

# %% [markdown]
# ### 1.1. Import libraries

# %%
import pandas as pd

from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### 1.2. Load Dataset

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# ## Part 2: Data Preparation

# %%
# Print the shape of the dataframe
df.shape
# Out:
# (1048, 65)

# %%
# Remove rows with missing values
df = df.dropna(subset=["is_match"])

# %%
# Change the column names to don't use underscores and to use upper first letters
df.columns = [col.replace('_', ' ').title() for col in df.columns]

# %%
# Convert categorical variables to numerical dummy variables using one-hot encoding
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Is Dater Male  Dater Age  Dated Age  Age Difference  Are Same Race  \
# 0          False         21         27               6          False
# 1          False         21         22               1          False
# 2          False         21         23               2          False
# 3          False         21         24               3          False
# 4          False         21         25               4          False
#
#    Same Race Importance For Dater  Same Religion Importance For Dater  \
# 0                             2.0                                 4.0
# 1                             2.0                                 4.0
# 2                             2.0                                 4.0
# 3                             2.0                                 4.0
# 4                             2.0                                 4.0
#
#    Attractiveness Importance For Dated  Sincerity Importance For Dated  \
# 0                                 35.0                            20.0
# 1                                 60.0                             0.0
# 2                                 30.0                             5.0
# 3                                 30.0                            10.0
# 4                                 50.0                             0.0
#
#    Intelligence Importance For Dated  ...  Dated Wants To Date  Is Match  \
# 0                               20.0  ...                False         0
# 1                                0.0  ...                False         0
# 2                               15.0  ...                 True         1
# 3                               20.0  ...                 True         1
# 4                               30.0  ...                 True         0
#
#    Dater Race_'Black/African American'  Dater Race_'Latino/Hispanic American'  \
# 0                                False                                  False
# 1                                False                                  False
# 2                                False                                  False
# 3                                False                                  False
# 4                                False                                  False
#
#    Dater Race_caucasian  Dater Race_other  \
# 0                 False             False
# 1                 False             False
# 2                 False             False
# 3                 False             False
# 4                 False             False
#
#    Dated Race_'Black/African American'  Dated Race_'Latino/Hispanic American'  \
# 0                                False                                  False
# 1                                False                                  False
# 2                                False                                  False
# 3                                False                                   True
# 4                                False                                  False
#
#    Dated Race_caucasian  Dated Race_other
# 0                  True             False
# 1                  True             False
# 2                  True             False
# 3                 False             False
# 4                  True             False
#
# [5 rows x 71 columns]

# %%
# Print the shape of the dataframe after cleaning
df.shape
# Out:
# (1048, 71)

# %%
# Define K-fold cross-validation
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %% [markdown]
# ## Part 3: Modelling --> Test of which variables to remove from dataset

# %%
# 8 fairness scenarios: include/exclude gender, race, religion
fairness_scenarios = {
    "1: include gender, race, religion": {
        "gender": True,
        "race": True,
        "religion": True
    },
    "2: include gender, race, exclude religion": {
        "gender": True,
        "race": True,
        "religion": False
    },
    "3: include gender, exclude race, religion": {
        "gender": True,
        "race": False,
        "religion": False
    },
    "4: include gender, religion, exclude race": {
        "gender": True,
        "race": False,
        "religion": True
    },
    "5: exclude gender, race, religion": {
        "gender": False,
        "race": False,
        "religion": False
    },
    "6: include race, religion, exclude gender": {
        "gender": False,
        "race": True,
        "religion": True
    },
    "7: include race, exclude gender, religion": {
        "gender": False,
        "race": True,
        "religion": False
    },
    "8: include religion, exclude gender, race": {
        "gender": False,
        "race": False,
        "religion": True
    }
}

# %%
# Function to prepare data for a given fairness scenario
def prepare_data_for_scenario(df, scenario):
    df_copy = df.copy()

# Remove columns that directly indicate dating preferences
    df_copy = df_copy.drop(
        columns=[
            "Dater Wants To Date",
            "Dated Wants To Date"
        ],
        errors="ignore"
    )

# Remove columns based on scenario
    if not scenario["gender"]:
        gender_cols = [c for c in df_copy.columns if "Gender" in c or "Male" in c or "Female" in c]
        df_copy = df_copy.drop(columns=gender_cols, errors="ignore")

    if not scenario["race"]:
        race_cols = [c for c in df_copy.columns if "Race" in c]
        df_copy = df_copy.drop(columns=race_cols, errors="ignore")

    if not scenario["religion"]:
        religion_cols = [c for c in df_copy.columns if "Religion" in c]
        df_copy = df_copy.drop(columns=religion_cols, errors="ignore")

    return df_copy

# %%
# Function to evaluate model using cross-validation and return mean F1 score
def evaluate_model_f1(model, X, y, cv):
    scores = cross_val_score(
        model,
        X,
        y,
        cv=cv,
        scoring="f1"
    )
    return scores.mean()

# %%
# Define models to evaluate
models = {
    "Baseline": DummyClassifier(strategy="most_frequent"),

    "Logistic Regression": Pipeline([
        ("scaler", StandardScaler()),
        ("log_reg", LogisticRegression(
            max_iter=1000,
            class_weight="balanced",
            C=1,
            penalty="l1",
            solver="liblinear"
        ))
    ]),

    "Decision Tree": DecisionTreeClassifier(
        max_depth=5,
        min_samples_split=5,
        min_samples_leaf=1,
        random_state=42
    ),

    "Random Forest": RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        min_samples_split=5,
        min_samples_leaf=2,
        random_state=42,
        n_jobs=-1
    ),

    "KNN": Pipeline([
        ("scaler", StandardScaler()),
        ("knn", KNeighborsClassifier(
            n_neighbors=15,
            weights="distance",
            p=2
        ))
    ])
}

# %%
# Evaluate models across fairness scenarios
results = []

for scenario_name, scenario in fairness_scenarios.items():
    df_scenario = prepare_data_for_scenario(df, scenario)

    X_s = df_scenario.drop(columns=["Is Match"])
    y_s = df_scenario["Is Match"]

    for model_name, model in models.items():
        f1 = evaluate_model_f1(model, X_s, y_s, cv)
        results.append({
            "Scenario": scenario_name,
            "Model": model_name,
            "F1-score": round(f1, 4)
        })

results_df = pd.DataFrame(results)

pivot_table = results_df.pivot(
    index="Scenario",
    columns="Model",
    values="F1-score"
)

pivot_table
# Out:
# Model                                      Baseline  Decision Tree     KNN  \
# Scenario
# 1: include gender, race, religion               0.0         0.3692  0.1670
# 2: include gender, race, exclude religion       0.0         0.4055  0.1582
# 3: include gender, exclude race, religion       0.0         0.4581  0.2408
# 4: include gender, religion, exclude race       0.0         0.4303  0.2454
# 5: exclude gender, race, religion               0.0         0.4538  0.2456
# 6: include race, religion, exclude gender       0.0         0.3802  0.1652
# 7: include race, exclude gender, religion       0.0         0.3970  0.1646
# 8: include religion, exclude gender, race       0.0         0.4323  0.2402
#
# Model                                      Logistic Regression  Random Forest
# Scenario
# 1: include gender, race, religion                       0.5032         0.3878
# 2: include gender, race, exclude religion               0.4997         0.3744
# 3: include gender, exclude race, religion               0.5233         0.3918
# 4: include gender, religion, exclude race               0.5212         0.3816
# 5: exclude gender, race, religion                       0.5213         0.3879
# 6: include race, religion, exclude gender               0.5012         0.3763
# 7: include race, exclude gender, religion               0.4975         0.3839
# 8: include religion, exclude gender, race               0.5280         0.3664
