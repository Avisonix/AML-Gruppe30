# %% [markdown]
# ## Part 1: Introduction

# %% [markdown]
# ### 1.1. Import libraries

# %%
import pandas as pd
import numpy as np 

# Sklearn modules for data splitting, preprocessing, model building and evaluation
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler

# Models to be used for classification
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# Visualization
import matplotlib.pyplot as plt
from sklearn import tree

# Evaluation metrics
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### 1.2. Load Dataset

# %%
df = pd.read_csv("../data/raw/train.csv") # stien til datafilen når det er i IdaData.ipynb
#df = pd.read_csv("../../data/raw/train.csv") # stien til datafilen når det er i data.ipynb

# %% [markdown]
# ## Part 2: Data Preparation

# %% [markdown]
# ### 2.1. Data Description and Inspection

# %%
# Print the shape of the dataframe
df.shape
# Out:
# (1048, 65)

# %%
# Print the first few rows of the dataframe
df.head()
# Out:
#    is_dater_male  dater_age  dated_age  age_difference  \
# 0          False         21         27               6
# 1          False         21         22               1
# 2          False         21         23               2
# 3          False         21         24               3
# 4          False         21         25               4
#
#                                 dater_race                  dated_race  \
# 0  'Asian/Pacific Islander/Asian-American'                   caucasian
# 1  'Asian/Pacific Islander/Asian-American'                   caucasian
# 2  'Asian/Pacific Islander/Asian-American'                   caucasian
# 3  'Asian/Pacific Islander/Asian-American'  'Latino/Hispanic American'
# 4  'Asian/Pacific Islander/Asian-American'                   caucasian
#
#    are_same_race  same_race_importance_for_dater  \
# 0          False                             2.0
# 1          False                             2.0
# 2          False                             2.0
# 3          False                             2.0
# 4          False                             2.0
#
#    same_religion_importance_for_dater  attractiveness_importance_for_dated  \
# 0                                 4.0                                 35.0
# 1                                 4.0                                 60.0
# 2                                 4.0                                 30.0
# 3                                 4.0                                 30.0
# 4                                 4.0                                 50.0
#
#    ...  interests_correlation  expected_satisfaction_of_dater  \
# 0  ...                   0.14                             3.0
# 1  ...                   0.54                             3.0
# 2  ...                   0.61                             3.0
# 3  ...                   0.21                             3.0
# 4  ...                   0.25                             3.0
#
#    expected_number_of_likes_of_dater_from_20_people  \
# 0                                                 2
# 1                                                 2
# 2                                                 2
# 3                                                 2
# 4                                                 2
#
#    expected_number_of_dates_for_dater  dater_liked_dated  \
# 0                                   4                7.0
# 1                                   4                7.0
# 2                                   4                7.0
# 3                                   4                6.0
# 4                                   4                6.0
#
#    probability_dated_wants_to_date  already_met_before  dater_wants_to_date  \
# 0                              6.0                True                 True
# 1                              5.0                True                 True
# 2                              6.0                True                 True
# 3                              6.0                True                 True
# 4                              5.0                True                False
#
#    dated_wants_to_date  is_match
# 0                False         0
# 1                False         0
# 2                 True         1
# 3                 True         1
# 4                 True         0
#
# [5 rows x 65 columns]

# %%
# Print the data types of each column
df.dtypes
# Out:
# is_dater_male                         bool
# dater_age                            int64
# dated_age                            int64
# age_difference                       int64
# dater_race                          object
#                                     ...
# probability_dated_wants_to_date    float64
# already_met_before                    bool
# dater_wants_to_date                   bool
# dated_wants_to_date                   bool
# is_match                             int64
# Length: 65, dtype: object

# %% [markdown]
# ### 2.2. Data Preprocessing and Cleaning

# %%
# Remove rows with missing values
df = df.dropna(subset=["is_match"])

# %%
# Change the column names to don't use underscores and to use upper first letters
df.columns = [col.replace('_', ' ').title() for col in df.columns]

# %%
# print all the column names
print(df.columns.tolist())
# Out:
# ['Is Dater Male', 'Dater Age', 'Dated Age', 'Age Difference', 'Dater Race', 'Dated Race', 'Are Same Race', 'Same Race Importance For Dater', 'Same Religion Importance For Dater', 'Attractiveness Importance For Dated', 'Sincerity Importance For Dated', 'Intelligence Importance For Dated', 'Humor Importance For Dated', 'Ambition Importance For Dated', 'Shared Interests Importance For Dated', 'Attractiveness Score Of Dater From Dated', 'Sincerity Score Of Dater From Dated', 'Intelligence Score Of Dater From Dated', 'Humor Score Of Dater From Dated', 'Ambition Score Of Dater From Dated', 'Shared Interests Score Of Dater From Dated', 'Attractiveness Importance For Dater', 'Sincerity Importance For Dater', 'Intelligence Importance For Dater', 'Humor Importance For Dater', 'Ambition Importance For Dater', 'Shared Interests Importance For Dater', 'Self Reported Attractiveness Of Dater', 'Self Reported Sincerity Of Dater', 'Self Reported Intelligence Of Dater', 'Self Reported Humor Of Dater', 'Self Reported Ambition Of Dater', 'Reported Attractiveness Of Dated From Dater', 'Reported Sincerity Of Dated From Dater', 'Reported Intelligence Of Dated From Dater', 'Reported Humor Of Dated From Dater', 'Reported Ambition Of Dated From Dater', 'Reported Shared Interests Of Dated From Dater', 'Dater Interest In Sports', 'Dater Interest In Tvsports', 'Dater Interest In Exercise', 'Dater Interest In Dining', 'Dater Interest In Museums', 'Dater Interest In Art', 'Dater Interest In Hiking', 'Dater Interest In Gaming', 'Dater Interest In Clubbing', 'Dater Interest In Reading', 'Dater Interest In Tv', 'Dater Interest In Theater', 'Dater Interest In Movies', 'Dater Interest In Concerts', 'Dater Interest In Music', 'Dater Interest In Shopping', 'Dater Interest In Yoga', 'Interests Correlation', 'Expected Satisfaction Of Dater', 'Expected Number Of Likes Of Dater From 20 People', 'Expected Number Of Dates For Dater', 'Dater Liked Dated', 'Probability Dated Wants To Date', 'Already Met Before', 'Dater Wants To Date', 'Dated Wants To Date', 'Is Match']

# %%
# Store all column names before making changes
cols_before = set(df.columns)

# Drop unwanted columns (gender, religion, etc.)
df = df.drop(
    columns=[
        "Dated Wants To Date",
        "Dater Wants To Date",
        "Same Race Importance For Dater",
        "Same Religion Importance For Dater"
    ],
    errors="ignore"  # ignore errors if any columns are missing
)

# Drop all columns containing the word 'Race'
race_cols = [col for col in df.columns if "Race" in col]
df = df.drop(columns=race_cols, errors="ignore")

# Compare column sets before and after to see which columns were removed for verification
cols_after = set(df.columns)
removed_cols = cols_before - cols_after

# Print removed columns
print("Removed columns:", removed_cols)
# Out:
# Removed columns: {'Same Race Importance For Dater', 'Dater Race', 'Same Religion Importance For Dater', 'Dater Wants To Date', 'Are Same Race', 'Dated Race', 'Dated Wants To Date'}

# %%
# Convert categorical variables to numerical dummy variables using one-hot encoding
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Is Dater Male  Dater Age  Dated Age  Age Difference  \
# 0          False         21         27               6
# 1          False         21         22               1
# 2          False         21         23               2
# 3          False         21         24               3
# 4          False         21         25               4
#
#    Attractiveness Importance For Dated  Sincerity Importance For Dated  \
# 0                                 35.0                            20.0
# 1                                 60.0                             0.0
# 2                                 30.0                             5.0
# 3                                 30.0                            10.0
# 4                                 50.0                             0.0
#
#    Intelligence Importance For Dated  Humor Importance For Dated  \
# 0                               20.0                        20.0
# 1                                0.0                        40.0
# 2                               15.0                        40.0
# 3                               20.0                        10.0
# 4                               30.0                        10.0
#
#    Ambition Importance For Dated  Shared Interests Importance For Dated  ...  \
# 0                            0.0                                    5.0  ...
# 1                            0.0                                    0.0  ...
# 2                            5.0                                    5.0  ...
# 3                           10.0                                   20.0  ...
# 4                            0.0                                   10.0  ...
#
#    Dater Interest In Shopping  Dater Interest In Yoga  Interests Correlation  \
# 0                         8.0                     1.0                   0.14
# 1                         8.0                     1.0                   0.54
# 2                         8.0                     1.0                   0.61
# 3                         8.0                     1.0                   0.21
# 4                         8.0                     1.0                   0.25
#
#    Expected Satisfaction Of Dater  \
# 0                             3.0
# 1                             3.0
# 2                             3.0
# 3                             3.0
# 4                             3.0
#
#    Expected Number Of Likes Of Dater From 20 People  \
# 0                                                 2
# 1                                                 2
# 2                                                 2
# 3                                                 2
# 4                                                 2
#
#    Expected Number Of Dates For Dater  Dater Liked Dated  \
# 0                                   4                7.0
# 1                                   4                7.0
# 2                                   4                7.0
# 3                                   4                6.0
# 4                                   4                6.0
#
#    Probability Dated Wants To Date  Already Met Before  Is Match
# 0                              6.0                True         0
# 1                              5.0                True         0
# 2                              6.0                True         1
# 3                              6.0                True         1
# 4                              5.0                True         0
#
# [5 rows x 58 columns]

# %%
# Print the shape of the dataframe after cleaning
df.shape
# Out:
# (1048, 58)

# %%
# Get summary statistics of the dataframe
df.describe()
# Out:
#          Dater Age    Dated Age  Age Difference  \
# count  1048.000000  1048.000000     1048.000000
# mean     25.005725    24.818702        3.032443
# std       3.270365     3.180581        2.427732
# min      18.000000    18.000000        0.000000
# 25%      22.000000    22.000000        1.000000
# 50%      25.000000    25.000000        2.000000
# 75%      27.000000    27.000000        4.000000
# max      35.000000    35.000000       14.000000
#
#        Attractiveness Importance For Dated  Sincerity Importance For Dated  \
# count                          1048.000000                     1048.000000
# mean                             23.728235                       16.971021
# std                              12.660571                        7.450629
# min                               5.000000                        0.000000
# 25%                              15.000000                       10.000000
# 50%                              20.000000                       18.000000
# 75%                              30.000000                       20.000000
# max                             100.000000                       40.000000
#
#        Intelligence Importance For Dated  Humor Importance For Dated  \
# count                        1048.000000                 1048.000000
# mean                           22.255887                   17.325029
# std                             7.352106                    6.666005
# min                             0.000000                    0.000000
# 25%                            20.000000                   10.832500
# 50%                            20.000000                   18.180000
# 75%                            25.000000                   20.000000
# max                            50.000000                   40.000000
#
#        Ambition Importance For Dated  Shared Interests Importance For Dated  \
# count                    1048.000000                            1048.000000
# mean                        9.725792                              10.333626
# std                         7.073420                               6.763784
# min                         0.000000                               0.000000
# 25%                         5.000000                               5.000000
# 50%                        10.000000                              10.000000
# 75%                        15.000000                              15.000000
# max                        53.000000                              30.000000
#
#        Attractiveness Score Of Dater From Dated  ...  Dater Interest In Music  \
# count                               1048.000000  ...              1048.000000
# mean                                   6.211355  ...                 7.710878
# std                                    1.964935  ...                 1.899931
# min                                    0.000000  ...                 1.000000
# 25%                                    5.000000  ...                 7.000000
# 50%                                    6.000000  ...                 8.000000
# 75%                                    8.000000  ...                 9.000000
# max                                   10.000000  ...                10.000000
#
#        Dater Interest In Shopping  Dater Interest In Yoga  \
# count                 1048.000000             1048.000000
# mean                     5.511450                4.133588
# std                      2.597821                2.696578
# min                      1.000000                1.000000
# 25%                      4.000000                2.000000
# 50%                      5.000000                3.000000
# 75%                      8.000000                7.000000
# max                     10.000000               10.000000
#
#        Interests Correlation  Expected Satisfaction Of Dater  \
# count            1048.000000                     1048.000000
# mean                0.154990                        5.378817
# std                 0.335816                        1.630245
# min                -0.630000                        1.000000
# 25%                -0.110000                        5.000000
# 50%                 0.150000                        5.000000
# 75%                 0.420000                        7.000000
# max                 0.900000                        9.000000
#
#        Expected Number Of Likes Of Dater From 20 People  \
# count                                       1048.000000
# mean                                           5.760496
# std                                            4.954703
# min                                            0.000000
# 25%                                            2.000000
# 50%                                            4.000000
# 75%                                            8.000000
# max                                           20.000000
#
#        Expected Number Of Dates For Dater  Dater Liked Dated  \
# count                         1048.000000        1048.000000
# mean                             2.844466           6.218034
# std                              2.370152           1.858517
# min                              0.000000           0.000000
# 25%                              1.000000           5.000000
# 50%                              2.000000           6.000000
# 75%                              4.000000           7.000000
# max                             10.000000          10.000000
#
#        Probability Dated Wants To Date     Is Match
# count                      1048.000000  1048.000000
# mean                          4.978053     0.177481
# std                           2.269876     0.382258
# min                           0.000000     0.000000
# 25%                           3.000000     0.000000
# 50%                           5.000000     0.000000
# 75%                           7.000000     0.000000
# max                          10.000000     1.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# ### 2.3. Split Features and Target Variable

# %%
# Split the data into features and target variable
# "Is Match" is the target variable and is binary (0 or 1) indicating if there was a match or not
X = df.drop("Is Match", axis=1)
y = df["Is Match"]

# 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20, # the dataset is small, so use 20% for testing
    stratify=y,
    random_state=42
)

print(f"Train: {len(X_train)}, Test: {len(X_test)}")

# Define K-fold cross-validation on the training data
# This 'cv' object will be used later when training/evaluating models
# CV means cross-validation
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)
# Out:
# Train: 838, Test: 210

# %% [markdown]
# ## Part 3: Modelling

# %% [markdown]
# ### 3.1. Baseline Model

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Baseline model: always predicts the most frequent class in y_train
dummy_clf = DummyClassifier(strategy='most_frequent')

# Train on the *original* training data
dummy_clf.fit(X_train, y_train)

# Predict on test data
y_pred_dummy = dummy_clf.predict(X_test)

# Metrics
accuracy_dummy = accuracy_score(y_test, y_pred_dummy)
precision_dummy = precision_score(y_test, y_pred_dummy, zero_division=0)
recall_dummy = recall_score(y_test, y_pred_dummy, zero_division=0)
f1_dummy = f1_score(y_test, y_pred_dummy, zero_division=0)

print("=== DummyClassifier (Most Frequent) ===")
print(f"Accuracy:  {accuracy_dummy:.3f}")
print(f"Precision: {precision_dummy:.3f}")
print(f"Recall:    {recall_dummy:.3f}")
print(f"F1-score:  {f1_dummy:.3f}\n")

print("Classification report:")
print(classification_report(y_test, y_pred_dummy, zero_division=0))

# Confusion matrix
cm_dummy = confusion_matrix(y_test, y_pred_dummy)
print("Confusion matrix:")
print(cm_dummy)

sns.heatmap(cm_dummy, annot=True, fmt="d")
plt.title("Dummy Classifier – Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# === DummyClassifier (Most Frequent) ===
# Accuracy:  0.824
# Precision: 0.000
# Recall:    0.000
# F1-score:  0.000
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       173
#            1       0.00      0.00      0.00        37
#
#     accuracy                           0.82       210
#    macro avg       0.41      0.50      0.45       210
# weighted avg       0.68      0.82      0.74       210
#
# Confusion matrix:
# [[173   0]
#  [ 37   0]]

# %% [markdown]
# ### 3.2. Logistic Regression

# %% [markdown]
# #### 3.2.1. Logistic Regression with Cross-Validation

# %%
# Build a pipeline: scaling + model
lr_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("log_reg", LogisticRegression(max_iter=1000))
])

# Run cross-validation on the training data with the different scoring metrics
# Accuracy
lr_acc_scores = cross_val_score(
    lr_pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring="accuracy"
)

# F1-score
lr_f1_scores = cross_val_score(
    lr_pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring="f1"
)

# Recall
lr_recall_scores = cross_val_score(
    lr_pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring="recall"
)

# Precision
lr_precision_scores = cross_val_score(
    lr_pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring="precision"
)

# Print the cross-validation scores
print("Logistic Regression CV Accuracy Scores:", lr_acc_scores)
print("Logistic Regression mean CV Accuracy Score:", lr_acc_scores.mean())

print("Logistic Regression CV F1 Scores:", lr_f1_scores)
print("Logistic Regression mean CV F1 Score:", lr_f1_scores.mean())

print("Logistic Regression CV Recall Scores:", lr_recall_scores)
print("Logistic Regression mean CV Recall Score:", lr_recall_scores.mean())

print("Logistic Regression CV Precision Scores:", lr_precision_scores)
print("Logistic Regression mean CV Precision Score:", lr_precision_scores.mean())
# Out:
# Logistic Regression CV Accuracy Scores: [0.85119048 0.8452381  0.8452381  0.8502994  0.86826347]
# Logistic Regression mean CV Accuracy Score: 0.8520459081836327
# Logistic Regression CV F1 Scores: [0.46808511 0.45833333 0.56666667 0.50980392 0.59259259]
# Logistic Regression mean CV F1 Score: 0.5190963241088398
# Logistic Regression CV Recall Scores: [0.36666667 0.36666667 0.56666667 0.44827586 0.53333333]
# Logistic Regression mean CV Recall Score: 0.45632183908045976
# Logistic Regression CV Precision Scores: [0.64705882 0.61111111 0.56666667 0.59090909 0.66666667]
# Logistic Regression mean CV Precision Score: 0.6164824717765894

# %% [markdown]
# #### 3.2.2. Fine-Tune Logistic Regression with GridSearchCV

# %%
# Hyperparameter grid
lr_param_grid = {
    "log_reg__C": [0.001, 0.01, 0.1, 1, 10, 100],
    "log_reg__penalty": ["l1", "l2"],
    "log_reg__solver": ["liblinear", "saga"],
    "log_reg__class_weight": [None, "balanced"],
}

# Evaluate several metrics and choose which one to optimize (refit)
scoring = {
    "accuracy": "accuracy",
    "f1": "f1",
    "recall": "recall", 
    "precision": "precision"
}

# Set up GridSearchCV with multiple scoring metrics
lr_grid = GridSearchCV(
    estimator=lr_pipeline,
    param_grid=lr_param_grid,
    cv=cv,
    scoring=scoring,
    refit="f1",                
    return_train_score=True,
    n_jobs=-1
)

# Fit the GridSearchCV to the training data
lr_grid.fit(X_train, y_train)

# Report best parameters and best score for the refit metric (F1)
print("Best params:", lr_grid.best_params_)
print("Best CV F1 (refit metric):", lr_grid.best_score_)


# Also report best scores for the other metrics for the selected best_index_
best_i = lr_grid.best_index_

# Get the cross-validation results
cvres = lr_grid.cv_results_

# Print CV scores for all metrics at the best F1 index
print("CV Accuracy at best F1:", cvres["mean_test_accuracy"][best_i])
print("CV Recall at best F1:",   cvres["mean_test_recall"][best_i])
print("CV F1 at best F1:",       cvres["mean_test_f1"][best_i])
print("CV Precision at best F1:",  cvres["mean_test_precision"][best_i])
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Best params: {'log_reg__C': 1, 'log_reg__class_weight': 'balanced', 'log_reg__penalty': 'l2', 'log_reg__solver': 'saga'}
# Best CV F1 (refit metric): 0.5375215129611046
# CV Accuracy at best F1: 0.7779868833761049
# CV Recall at best F1: 0.7248275862068965
# CV F1 at best F1: 0.5375215129611046
# CV Precision at best F1: 0.42915667665667667
# Exception ignored in: <function ResourceTracker.__del__ at 0x102af1bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x106811bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x104bd9bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x102d65bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x107101bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10672dbc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x102fd5bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x103b25bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes

# %% [markdown]
# #### 3.3. Decision Tree

# %%
# Decision Tree without scaling (tree models are scale-invariant)
dt_model = DecisionTreeClassifier(
    random_state=42
)

# Run cross-validation on the training data for performance evaluation
dt_cv_scores = cross_val_score(
    dt_model,
    X_train,
    y_train,
    cv=cv,
    scoring="accuracy"
)

# Print Decision Tree CV scores
print("Decision Tree CV scores:", dt_cv_scores)
print("Decision Tree mean CV score:", dt_cv_scores.mean())
# Out:
# Decision Tree CV scores: [0.83928571 0.83928571 0.79166667 0.74850299 0.76047904]
# Decision Tree mean CV score: 0.7958440262332478

# %% [markdown]
# ##### 3.3.1. Reduced Decision Tree for Visualization

# %%
# Create a reduced Decision Tree for visualization with max depth of 3
dtree_small = DecisionTreeClassifier(
    random_state=42,
    max_depth=3
)

# Fit the reduced Decision Tree model on the training data
dtree_small.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
# Visualize the Decision Tree
# Create a figure with specified size
plt.figure(figsize=(13, 8))

# Plot the tree
tree.plot_tree(
    dtree_small,
class_names=["Unsuccessful Match", "Successful Match"],
    feature_names=list(X_train.columns),
    filled=True,
    fontsize=10
)

# Save the figure
plt.savefig("reduced_tree.png", bbox_inches="tight")

# Show the plot
plt.show()

# %% [markdown]
# #### 3.4. Random Forest

# %%
# Random Forest without scaling
rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# Run cross-validation on the training data
rf_cv_scores = cross_val_score(
    rf_model,
    X_train,
    y_train,
    cv=cv,
    scoring="accuracy"
)

# Print Random Forest CV scores
print("Random Forest CV scores:", rf_cv_scores)
print("Random Forest mean CV score:", rf_cv_scores.mean())
# Out:
# Random Forest CV scores: [0.85119048 0.86904762 0.85119048 0.85628743 0.8502994 ]
# Random Forest mean CV score: 0.8556030795551754

# %% [markdown]
# #### 3.4.1 Random Forest tuning

# %%
# Parameter grid 
rf_param_grid = {
    "n_estimators": [200, 500],                 
    "max_depth": [None, 5, 10, 20],             
    "min_samples_split": [2, 5, 10],            
    "min_samples_leaf": [1, 2, 4],              
    "max_features": ["sqrt", "log2"],            
    "bootstrap": [True]                         
}

# Grid search
rf_grid = GridSearchCV(
    estimator=rf_model,
    param_grid=rf_param_grid,
    cv=cv,                                      
    scoring="accuracy",
    n_jobs=-1,
    verbose=2,
    return_train_score=True
)

# Fit on training data
rf_grid.fit(X_train, y_train)

print("RF best params:", rf_grid.best_params_)
print("RF best CV accuracy:", rf_grid.best_score_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# ...
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.8s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   1.0s
# RF best params: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# RF best CV accuracy: 0.860386370116909

# %% [markdown]
# #### 3.5. K-Nearest Neighbors

# %%
knn_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("knn", KNeighborsClassifier(
        n_neighbors=15,
        weights="distance",
        p=2
    ))
])

knn_cv_scores = cross_val_score(
    knn_pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring="accuracy"
)


print("KNN CV scores (scaled):", knn_cv_scores)
print("KNN mean CV score (scaled):", knn_cv_scores.mean())
# Out:
# KNN CV scores (scaled): [0.83333333 0.85119048 0.83928571 0.84431138 0.8502994 ]
# KNN mean CV score (scaled): 0.8436840604505275

# %% [markdown]
# ### 3.5.1 KNN tuning

# %%
param_grid = {
    "scaler": [StandardScaler(), RobustScaler(), "passthrough"],
    "knn__n_neighbors": [3, 6, 9,12,15,19, 24, 48, 96],
    "knn__weights": ["uniform", "distance"],
    "knn__p": [1, 2],                      # 1=Manhattan, 2=Euclidean
}

KNN_grid = GridSearchCV(
    estimator=knn_pipeline,
    param_grid=param_grid,
    cv=cv,                                 
    scoring="accuracy",                    
    return_train_score=True,
    n_jobs=-1,
    verbose=3
)

KNN_grid.fit(X_train, y_train)

print("Best params:", KNN_grid.best_params_)
print("Best CV score:", KNN_grid.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 2/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.876, test=0.833) total time=   0.1s
# [CV 1/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.879, test=0.815) total time=   0.1s
# [CV 3/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.891, test=0.804) total time=   0.1s
# [CV 4/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.900, test=0.802) total time=   0.1s
# [CV 2/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.876, test=0.839) total time=   0.1s
# [CV 5/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.879, test=0.814) total time=   0.1s
# [CV 1/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.872, test=0.815) total time=   0.1s
# [CV 3/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.887, test=0.804) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.869, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.897, test=0.784) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.876, test=0.802) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.867, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.872, test=0.784) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.875, test=0.774) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.888, test=0.778) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.802) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.815) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.778) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.815) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.802) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.780) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.784) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.784) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.879, test=0.810) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.896, test=0.798) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.879, test=0.815) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.896, test=0.802) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.888, test=0.790) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.878, test=0.810) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.884, test=0.786) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.882, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.802) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.790) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.887, test=0.808) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.888, test=0.796) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.875, test=0.798) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.863, test=0.810) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.815) total time=   0.1s
# [CV 3/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.786) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.810) total time=   0.1s
# [CV 5/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.808) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.885, test=0.790) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.796) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.798) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.804) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.810) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.867, test=0.810) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.804) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.873, test=0.826) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.790) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.804) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.851, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.857, test=0.810) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.848, test=0.838) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.852, test=0.802) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.854, test=0.815) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.842, test=0.815) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.840, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.848, test=0.802) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.843, test=0.845) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.837, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.854, test=0.796) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.848, test=0.833) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.849, test=0.838) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.855, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.790) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.802) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.854, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.846, test=0.857) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.849, test=0.844) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.857, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.814) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.814) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.861, test=0.802) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.845, test=0.827) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.854, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.846, test=0.832) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.852, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.796) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.851, test=0.844) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.798) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.849, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.851) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.854, test=0.851) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.863, test=0.808) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.798) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.810) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.841, test=0.814) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.851, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.851) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.808) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.810) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.804) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.852, test=0.850) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.814) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.790) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.808) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.857) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.845, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.846, test=0.814) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.810) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.854, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.851, test=0.832) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.815) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.808) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.842, test=0.845) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.841, test=0.808) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.808) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.843, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.851, test=0.814) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.815) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.852, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.844, test=0.832) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.854, test=0.839) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.840, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.815) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.852, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.846, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.808) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.836, test=0.851) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.844, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.860, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.852, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.842, test=0.833) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.845, test=0.815) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.848, test=0.838) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.856) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.857, test=0.827) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.814) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.849, test=0.850) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.855, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.840, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.851) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.838) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.1s
# [CV 1/5] END knn__n_neighbors=9, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.815) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.849, test=0.839) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.855, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.857, test=0.814) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.845, test=0.839) total time=   0.1s
# [CV 4/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.854, test=0.820) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.842, test=0.820) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=9, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.860, test=0.832) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.843, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.845, test=0.826) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.833, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.814) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.848, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.838, test=0.850) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.845) total time=   0.1s
# [CV 2/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.841, test=0.826) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.840, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.838, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.851, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.839, test=0.851) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.839, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.841, test=0.844) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.833, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.830, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.851, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.830, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.837, test=0.845) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.839, test=0.810) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.856) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.842, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.848, test=0.838) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.814) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.825, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.849, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.804) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.836, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.845, test=0.844) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.848, test=0.851) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.849, test=0.844) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.842, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.838, test=0.826) total time=   0.0s[CV 5/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.851, test=0.832) total time=   0.0s
#
# [CV 1/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.846, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.851) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.839, test=0.845) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.840, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.848, test=0.832) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.846, test=0.826) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.814) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.838, test=0.844) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.848, test=0.845) total time=   0.1s
# [CV 1/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.843, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.851, test=0.845) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.833, test=0.851) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.838, test=0.820) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.836, test=0.845) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.842, test=0.850) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.854, test=0.845) total time=   0.1s
# [CV 1/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.849, test=0.833) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.846, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.808) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.839, test=0.810) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.854, test=0.850) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.829, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.824, test=0.827) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.850) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.857, test=0.857) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.846, test=0.844) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.845, test=0.833) total time=   0.1s
# [CV 2/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.851) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.834, test=0.815) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.838) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.810) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.851, test=0.845) total time=   0.1s
# [CV 2/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.848, test=0.826) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.830, test=0.832) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.846, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.815) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.846, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.851) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=15, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.848, test=0.839) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.831, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.841, test=0.832) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.845, test=0.826) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.845) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.833, test=0.838) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.834, test=0.845) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.838) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.842, test=0.820) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.843, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.851) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.832, test=0.814) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.846, test=0.833) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.838) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.840, test=0.845) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.833, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.831, test=0.845) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.837, test=0.839) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=19, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.849, test=0.839) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=19, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.831, test=0.810) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.837, test=0.839) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.839, test=0.850) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=19, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.824, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.831, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=19, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.844) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=19, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.842, test=0.839) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=19, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.824, test=0.827) total time=   0.0s
# ...
# [CV 3/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.831, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.830, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.823, test=0.826) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.829, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.838) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.831, test=0.827) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.834, test=0.833) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.823, test=0.820) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.830, test=0.827) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.824, test=0.821) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.831, test=0.833) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.838) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.829, test=0.838) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.831, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.825, test=0.833) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.823, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.830, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.829, test=0.832) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.1s
# [CV 1/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.828, test=0.827) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.832) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.830, test=0.826) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.838) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.839) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.827, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.824, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.826, test=0.832) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.821, test=0.826) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.826, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.833) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.823, test=0.820) total time=   0.1s
# [CV 2/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.821, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.827) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.823, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.821, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.821, test=0.826) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.823, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.821, test=0.826) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.821, test=0.826) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.823, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.823, test=0.820) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 2/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.821, test=0.826) total time=   0.0s
# [CV 3/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.821) total time=   0.0s
# [CV 5/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.820) total time=   0.0s
# [CV 4/5] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 1/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.822, test=0.821) total time=   0.1s
# [CV 5/5] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.823, test=0.820) total time=   0.0s
# Best params: {'knn__n_neighbors': 15, 'knn__p': 1, 'knn__weights': 'uniform', 'scaler': StandardScaler()}
# Best CV score: 0.8448602794411177

# %% [markdown]
# ### 4. Results and Evaluation
# #### 4.1. Results From the Models

# %%
# Collect results from the models
# Results before hyperparameter tuning
results_before = {
    "Logistic Regression": lr_cv_scores.mean(),
    "Decision Tree": dt_cv_scores.mean(),
    "Random Forest": rf_cv_scores.mean(),
    "KNN": knn_cv_scores.mean()
}

# Results after hyperparameter tuning - using accuracy
results_after_accuracy = {
    "Logistic Regression": lr_grid_accuracy.best_score_,
    "Decision Tree": 0,
    "Random Forest": rf_grid.best_score_,
    "KNN": KNN_grid.best_score_
}

# Results after hyperparameter tuning - using recall
results_after_recall = {
    "Logistic Regression": lr_grid_recall.best_score_,
    "Decision Tree": 0,
    "Random Forest": 0,
    "KNN": 0
}

# Results after hyperparameter tuning - using f1-score
results_after_fi = {
    "Logistic Regression": lr_grid_f1.best_score_,
    "Decision Tree": 0,
    "Random Forest": 0,
    "KNN": 0
}

# Convert to a table
results_table = pd.DataFrame({
    "Model": list(results_before.keys()),
    "Accuracy Before Tuning": [round(v, 4) for v in results_before.values()],
    "Accuracy After Tuning": [round(v, 4) for v in results_after_accuracy.values()],
    "Recall After Tuning": [round(v, 4) for v in results_after_recall.values()],
    "F1-Score After Tuning": [round(v, 4) for v in results_after_fi.values()]
})

# Display results
results_table.reset_index(drop=True)
# Out:
#                  Model  Accuracy Before Tuning  Accuracy After Tuning  \
# 0  Logistic Regression                  0.8509                 0.8664
# 1        Decision Tree                  0.7958                 0.0000
# 2        Random Forest                  0.8556                 0.8604
# 3                  KNN                  0.8437                 0.8449
#
#    Recall After Tuning  F1-Score After Tuning
# 0                0.892                 0.5517
# 1                0.000                 0.0000
# 2                0.000                 0.0000
# 3                0.000                 0.0000
# Exception ignored in: <function ResourceTracker.__del__ at 0x103ed1bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x106b91bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x108939bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1070e9bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1048d1bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x110965bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x103f01bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x105cb9bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes

# %% [markdown]
# ### ?. Test Performance
